# %% [markdown]
# # Exploratory Data Analysis - Heart Disease Dataset
#
# This notebook performs comprehensive EDA on the Heart Disease UCI dataset.

# %%
# %pip install pandas
# %pip install numpy
# %pip install scikit-learn
# %pip install matplotlib
# %pip install seaborn
# Out:
# Requirement already satisfied: pandas in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/Durgesh/Documents/python_project/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load data
df = pd.read_csv('../data/raw/heart_disease.csv')
print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# Dataset shape: (920, 14)
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       2
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %%
# Basic info
print("Dataset Info:")
print(df.info())
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    float64
#  1   sex       920 non-null    float64
#  2   cp        920 non-null    float64
#  3   trestbps  861 non-null    float64
#  4   chol      890 non-null    float64
#  5   fbs       830 non-null    float64
#  6   restecg   918 non-null    float64
#  7   thalach   865 non-null    float64
#  8   exang     865 non-null    float64
#  9   oldpeak   858 non-null    float64
#  10  slope     611 non-null    float64
#  11  ca        309 non-null    float64
#  12  thal      434 non-null    float64
#  13  target    920 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 100.8 KB
# None
#
# Missing values:
# age           0
# sex           0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalach      55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# target        0
# dtype: int64

# %%
# Statistical summary
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  920.000000  920.000000  920.000000  861.000000  890.000000  830.000000
# mean    53.510870    0.789130    3.250000  132.132404  199.130337    0.166265
# std      9.424685    0.408148    0.930969   19.066070  110.780810    0.372543
# min     28.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     47.000000    1.000000    3.000000  120.000000  175.000000    0.000000
# 50%     54.000000    1.000000    4.000000  130.000000  223.000000    0.000000
# 75%     60.000000    1.000000    4.000000  140.000000  268.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  603.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  918.000000  865.000000  865.000000  858.000000  611.000000  309.000000
# mean     0.604575  137.545665    0.389595    0.878788    1.770867    0.676375
# std      0.805827   25.926276    0.487941    1.091226    0.619256    0.935653
# min      0.000000   60.000000    0.000000   -2.600000    1.000000    0.000000
# 25%      0.000000  120.000000    0.000000    0.000000    1.000000    0.000000
# 50%      0.000000  140.000000    0.000000    0.500000    2.000000    0.000000
# 75%      1.000000  157.000000    1.000000    1.500000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal      target
# count  434.000000  920.000000
# mean     5.087558    0.995652
# std      1.919075    1.142693
# min      3.000000    0.000000
# 25%      3.000000    0.000000
# 50%      6.000000    1.000000
# 75%      7.000000    2.000000
# max      7.000000    4.000000

# %%
# Target distribution
plt.figure(figsize=(10, 6))
target_counts = df['target'].value_counts()
plt.bar(['No Disease', 'Disease'], target_counts.values, color=['skyblue', 'salmon'])
plt.title('Target Variable Distribution')
plt.ylabel('Count')
plt.show()
print(f"Class balance:\n{target_counts}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 plt.figure(figsize=(10, 6))
#       3 target_counts = df['target'].value_counts()
# ----> 4 plt.bar(['No Disease', 'Disease'], target_counts.values, color=['skyblue', 'salmon'])
#       5 plt.title('Target Variable Distribution')
#       6 plt.ylabel('Count')
#
# File ~/Documents/python_project/venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)
#    2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
#    2994         align=align,
#    2995         **({"data": data} if data is not None else {}),
#    2996         **kwargs,
#    2997     )
#
# File ~/Documents/python_project/venv/lib/python3.10/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/python_project/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2583, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2580     if yerr is not None:
#    2581         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2583 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2584     # Make args iterable too.
#    2585     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2587 # Now that units have been converted, set the tick locations.
#    2588 if orientation == 'vertical':
#
# File ~/Documents/python_project/venv/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~/Documents/python_project/venv/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (2,) and arg 1 with shape (5,).

# %%
# Correlation heatmap
plt.figure(figsize=(14, 10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f')
plt.title('Feature Correlation Heatmap')
plt.tight_layout()
plt.savefig('../screenshots/correlation_heatmap.png', dpi=150)
plt.show()

# %%
# Distribution plots for key features
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('Feature Distributions', fontsize=16)

features_to_plot = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'cp']
for idx, feature in enumerate(features_to_plot):
    row = idx // 3
    col = idx % 3
    axes[row, col].hist(df[feature].dropna(), bins=30, edgecolor='black')
    axes[row, col].set_title(f'{feature}')
    axes[row, col].set_xlabel(feature)
    axes[row, col].set_ylabel('Frequency')

plt.tight_layout()
plt.savefig('../screenshots/feature_distributions.png', dpi=150)
plt.show()

# %%
# Box plots for numeric features by target
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('Feature Distributions by Target', fontsize=16)

numeric_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']
for idx, feature in enumerate(numeric_features):
    row = idx // 3
    col = idx % 3
    df.boxplot(column=feature, by='target', ax=axes[row, col])
    axes[row, col].set_title(f'{feature} by Target')
    axes[row, col].set_xlabel('Target')

plt.tight_layout()
plt.savefig('../screenshots/boxplots_by_target.png', dpi=150)
plt.show()
